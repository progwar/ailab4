# %%
import pandas as pd

s = pd.Series([5, 15, 25, 35, 45], index=['a', 'b', 'c', 'd', 'e'])

print(s)
print(f"Тип данных: {s.dtype}")
# Out:
# a     5
# b    15
# c    25
# d    35
# e    45
# dtype: int64
# Тип данных: int64
