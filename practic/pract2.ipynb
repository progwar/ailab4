# %%
import pandas as pd

s = pd.Series([12, 24, 36, 48, 60], index=['A', 'B', 'C', 'D', 'E'])

print("Исходный Series:")
print(s)

element_loc = s.loc['C']
print(f"1. Элемент с индексом 'C': {element_loc}")

element_iloc = s.iloc[2]
print(f"2. Третий элемент: {element_iloc}")
# Out:
# Исходный Series:
# A    12
# B    24
# C    36
# D    48
# E    60
# dtype: int64
# 1. Элемент с индексом 'C': 36
# 2. Третий элемент: 36
