# %%
import pandas as pd
import numpy as np

random_numbers = np.random.randint(1, 101, 50)
s = pd.Series(random_numbers)

print("Весь Series (50 элементов):")
print(s)

print("Первые 7 элементов:")
print(s.head(7))

print("Последние 5 элементов:")
print(s.tail(5))
# Out:
# Весь Series (50 элементов):
# 0     27
# 1      9
# 2     79
# 3     15
# 4     90
# 5     42
# 6     77
# 7     51
# 8     63
# 9     96
# 10    52
# 11    96
# 12     4
# 13    94
# 14    23
# 15    15
# 16    43
# 17    29
# 18    36
# 19    13
# 20    32
# 21    71
# 22    59
# 23    86
# 24    28
# 25    66
# 26    42
# 27    45
# 28    62
# 29    57
# 30     6
# 31    28
# 32    28
# 33    44
# 34    84
# 35    30
# 36    62
# 37    75
# 38    92
# 39    89
# 40    62
# 41    97
# 42     1
# 43    27
# 44    62
# 45    77
# 46     3
# 47    70
# 48    72
# 49    27
# dtype: int32
# Первые 7 элементов:
# 0    27
# 1     9
# 2    79
# 3    15
# 4    90
# 5    42
# 6    77
# dtype: int32
# Последние 5 элементов:
# 45    77
# 46     3
# 47    70
# 48    72
# 49    27
# dtype: int32
