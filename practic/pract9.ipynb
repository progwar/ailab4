# %%
import pandas as pd
import numpy as np

s = pd.Series([2, 4, 6, 8, 10])

print("Исходный Series:")
print(s)

s_sqrt = s.apply(np.sqrt)

print("Квадратный корень каждого элемента:")
print(s_sqrt)
# Out:
# Исходный Series:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# Квадратный корень каждого элемента:
# 0    1.414214
# 1    2.000000
# 2    2.449490
# 3    2.828427
# 4    3.162278
# dtype: float64
